# %%
import os
from datetime import datetime

# %%
directory = "files"
filenames = os.listdir(directory)

print(filenames)
# Out:
# ['b.txt', 'c.txt', 'd.txt', 'e.txt']

# %%
current_date = datetime.now().strftime("%Y-%m-%d")

for filename in filenames:
    filepath = os.path.join(directory, filename)
    new_filename = f"{filename[:-4]}-{current_date}.txt"
    new_filepath = os.path.join(directory, new_filename)

    os.rename(filepath, new_filepath)
    print(f"File '{filename}' is renamed to '{new_filename}'")
# Out:
# File 'b.txt' is renamed to 'b-2025-12-28.txt'
# File 'c.txt' is renamed to 'c-2025-12-28.txt'
# File 'd.txt' is renamed to 'd-2025-12-28.txt'
# File 'e.txt' is renamed to 'e-2025-12-28.txt'
