# %%
import streamlit as st
import pandas as pd

# %%
df = pd.read_csv("earthquakes_yesterday.csv")
df.head()
# Out:
#    Magnitude                         Location   Latitude   Longitude
# 0       0.77             7 km WNW of Cobb, CA  38.835999 -122.796501
# 1       1.09        2 km N of The Geysers, CA  38.792999 -122.759163
# 2       0.50  30 km NNE of Darwin, California  36.536600 -117.518800
# 3       0.79       2 km NNE of Loma Linda, CA  34.068667 -117.249333
# 4       1.32         9 km WSW of Beaumont, CA  33.887333 -117.056831

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index=0, Magnitude=0.77, Location='7 km WNW of Cobb, CA', Latitude=38.8359985351562, Longitude=-122.796501159668)
# Pandas(Index=1, Magnitude=1.09, Location='2 km N of The Geysers, CA', Latitude=38.7929992675781, Longitude=-122.759162902832)
# Pandas(Index=2, Magnitude=0.5, Location='30 km NNE of Darwin, California', Latitude=36.5366, Longitude=-117.5188)
# Pandas(Index=3, Magnitude=0.79, Location='2 km NNE of Loma Linda, CA', Latitude=34.0686667, Longitude=-117.2493333)
# Pandas(Index=4, Magnitude=1.32, Location='9 km WSW of Beaumont, CA', Latitude=33.8873329, Longitude=-117.0568314)
# Pandas(Index=5, Magnitude=1.03, Location='4 km NW of The Geysers, CA', Latitude=38.7986679077148, Longitude=-122.793502807617)
# Pandas(Index=6, Magnitude=0.87, Location='11 km NE of San Martin, CA', Latitude=37.1534996032715, Longitude=-121.526496887207)
# Pandas(Index=7, Magnitude=-0.1, Location='47 km ESE of Beatty, Nevada', Latitude=36.7696, Longitude=-116.2566)
# ...
