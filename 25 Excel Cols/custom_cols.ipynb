# %%
import pandas as pd

# %%
df = pd.read_excel("Input.xlsx")
df.head()
# Out:
#    Order Date    Product     Category  Price  Quantity
# 0  2023-01-01  Product A  Electronics    500         2
# 1  2023-01-03  Product B     Clothing     40         3
# 2  2023-01-05  Product C  Electronics   1200         1
# 3  2023-02-10  Product A  Electronics    500         1
# 4  2023-02-15  Product B     Clothing     40         2

# %%
df["Total"] = df["Price"] * df["Quantity"]
df.head()
# Out:
#    Order Date    Product     Category  Price  Quantity  Total
# 0  2023-01-01  Product A  Electronics    500         2   1000
# 1  2023-01-03  Product B     Clothing     40         3    120
# 2  2023-01-05  Product C  Electronics   1200         1   1200
# 3  2023-02-10  Product A  Electronics    500         1    500
# 4  2023-02-15  Product B     Clothing     40         2     80

# %%
df.head()
# Out:
#    Order Date    Product     Category  Price  Quantity  Total
# 0  2023-01-01  Product A  Electronics    500         2   1000
# 1  2023-01-03  Product B     Clothing     40         3    120
# 2  2023-01-05  Product C  Electronics   1200         1   1200
# 3  2023-02-10  Product A  Electronics    500         1    500
# 4  2023-02-15  Product B     Clothing     40         2     80

# %%
df.to_excel("output.xlsx", index=False)
